# %% [markdown]
# ## 1. Import the Libraries

# %%
import pandas as pd
import numpy as np

import recordlinkage

# %% [markdown]
# ## 2. Load the datasets for dictionary and the user search

# %%
df_dictionary = pd.read_csv("dictionary_companies.csv")
df_search_entries = pd.read_csv("search_entry.csv")
dfD = pd.read_csv("companies_dict.csv")

# Using dfA and dfB for easy reference
dfA = df_dictionary
dfB = df_search_entries

# %%
dfA
# Out:
#        id                             name  \
# 0       1                 1 MOBILE LIMITED
# 1       2                       1 TECH LTD
# 2       3                 23 SNAPS LIMITED
# 3       4             2E2 SERVICES LIMITED
# 4       5                   2E2 UK LIMITED
# 5       6                  40 50 MEDIA LTD
# 6       7          4D DATA CENTRES LIMITED
# 7       8               4GETMOBILE LIMITED
# 8       9           4SL CONSULTING LIMITED
# 9      10             4TC SERVICES LIMITED
# 10     11               A-INFINITY LIMITED
# 11     12          A-TEK SOLUTIONS LIMITED
# 12     13                  A.I. TALENT LTD
# 13     14                  AAA CONSULT LTD
# 14     15        AARDVARK UPRISING LIMITED
# 15     16                   AB TECHSYS LTD
# 16     17                   ABLINX LIMITED
# 17     18                     ABSU LIMITED
# 18     19                ABV SOLUTIONS LTD
# 19     20        ACTION FOR THE FUTURE LTD
# 20     21       ACTIVATED THINKING LIMITED
# 21     22         ACTIVON PROJECTS LIMITED
# 22     23                  ACTURIS LIMITED
# 23     24       AD PEPPER MEDIA UK LIMITED
# 24     25                   ADCOMPASS LTD.
# 25     26                  ADD TO CART LTD
# 26     27            ADFORM LONDON LIMITED
# 27     28                  ADLUDIO LIMITED
# 28     29            AFIN-IT GROUP LIMITED
# 29     30          AFTER THE FLOOD LIMITED
# ..    ...                              ...
# 970   971                   01SOLUTION LTD
# 971   972                     08845746 LTD
# 972   973                     0902 LIMITED
# 973   974                   0PT1MATES LTD.
# 974   975                 0TENTIC8 LIMITED
# 975   976                        1 B C LTD
# 976   977        1 CHOICE INTERNET LIMITED
# 977   978                  1 MEDIA LIMITED
# 978   979                1 MINUS 1 LIMITED
# 979   980                      1 ONION LTD
# 980   981               1 STOP WEB LIMITED
# 981   982             1&1 INTERNET LIMITED
# 982   983                  10 CREATIVE LTD
# 983   984        10 DIGITAL LADIES LIMITED
# 984   985                10 SQUARE LIMITED
# 985   986  10000 VOLT TECHNOLOGIES LIMITED
# 986   987                    10001 LIMITED
# 987   988                  1001 VM LIMITED
# 988   989             100STARLINGS LIMITED
# 989   990                    100X TECH LTD
# 990   991                      101 CAD LTD
# 991   992                   101 IT LIMITED
# 992   993            101 NET SOLUTIONS LTD
# 993   994            101 SOLUTIONS LIMITED
# 994   995             101 SYSTEM WORKS LTD
# 995   996                  101 WEB LIMITED
# 996   997                101DOMAIN LIMITED
# 997   998                 101SMART LIMITED
# 998   999          1045 DESIGN STUDIOS LTD
# 999  1000             10DUKE SOFTWARE LTD.
#
#                                                   addr  \
# 0                                         30 CITY ROAD
# 1                               57 CHARTERHOUSE STREET
# 2                                16 BOWLING GREEN LANE
# 3                 200 200 ALDERSGATE ALDERSGATE STREET
# 4                     200 ALDERSGATE ALDERSGATE STREET
# 5                              145-157 ST JOHN STREET
# 6                                         30 CITY ROAD
# 7                             152 KEMP HOUSE CITY ROAD
# 8                                         4 SNOW HILL
# 9                                    355 GOSWELL ROAD
# 10         AKIN PALMER LLP 3, ANGEL GATE 326 CITY ROAD
# 11                        KEMP HOUSE 152-160 CITY ROAD
# 12                       LONGBOW HOUSE CHISWELL STREET
# 13                   2ND FLOOR 145-157 ST. JOHN STREET
# 14                         UNIT 36 88-90 HATTON GARDEN
# 15              INTERNATIONAL HOUSE 24 HOLBORN VIADUCT
# 16                 7TH FLOOR, 16 ST. MARTIN'S LE GRAND
# 17                 THIRD FLOOR 111 CHARTERHOUSE STREET
# 18   C/O CAYOS CONSULTING SERVICES 40 BOWLING GREEN...
# 19                             145-157 ST JOHN STREET
# 20                            KEMP HOUSE 152 CITY ROAD
# 21              INTERNATIONAL HOUSE 24 HOLBORN VIADUCT
# 22                   COURTYARD SUITE 100 HATTON GARDEN
# 23                                 20 FARRINGDON ROAD
# 24                                6-8 SYCAMORE STREET
# 25                             145-157 ST JOHN STREET
# 26                       GATE HOUSE 1 ST JOHN'S SQUARE
# 27                   1 HARDWICK STREET HARDWICK STREET
# 28                            KEMP HOUSE 160 CITY ROAD
# 29                            140-142 ST. JOHN STREET
# ..                                                 ...
# 970                      1417/1419 LONDON ROAD NORBURY
# 971                               58 BULSTRODE AVENUE
# 972                                  7 ST JOHN'S ROAD
# 973         UNIT 11 HOVE BUSINESS CENTRE FONTHILL ROAD
# 974                                10 FINSBURY SQUARE
# 975                                 79 STANLEY AVENUE
# 976                             5 BEACON CLOSE FARNHAM
# 977  UNIT 3A KIRKBY LONSDALE BUSINESS PARK KIRKBY L...
# 978       MOLEX HOUSE THE MILLENNIUM CENTRE CROSBY WAY
# 979                                    53 BALHAM GROVE
# 980                                   239 ILFORD LANE
# 981               DISCOVERY HOUSE 154 SOUTHGATE STREET
# 982                     28 WIMPOLE ROAD GREAT EVERSDEN
# 983                                     48 DEFOE ROAD
# 984  SUITE 1, ARMCON BUSINESS PARK LONDON ROAD SOUT...
# 985           1ST FLOOR 314 REGENTS PARK ROAD FINCHLEY
# 986                                   19 REDDOWN ROAD
# 987                          169 SEABANK ROAD WALLASEY
# 988                 DEVONSHIRE HOUSE 582 HONEYPOT LANE
# 989         UNIT 11 HOVE BUSINESS CENTRE FONTHILL ROAD
# 990                                  92A STATION ROAD
# 991                           30 MARKET PLACE SWAFFHAM
# 992     THE OLD BANK, 205 - 207 HIGH STREET, COTTENHAM
# 993                        45-47 HIGH STREET 2ND FLOOR
# 994                         101 ORCHARD ROAD ERDINGTON
# 995         17 MIDLAND COURT, STATION APPROACH, OAKHAM
# 996        C/O FLETCHER KENNEDY LIMITED 72 HIGH STREET
# 997                      UNIT 15 BEECH AVENUE TAVERHAM
# 998  10TH FLOOR, K &amp; B ACCOUNTANCY GROUP ONE CA...
# 999                                      2 WATER LANE
#
#                            city ctry      code
# 0                        LONDON   UK  EC1Y 2AB
# 1                        LONDON   UK  EC1M 6HA
# 2                        LONDON   UK  EC1R 0BD
# 3                        LONDON   UK  EC1A 4HD
# 4                        LONDON   UK  EC1A 4HD
# 5                        LONDON   UK  EC1V 4PW
# 6                        LONDON   UK   EC1 2AB
# 7                        LONDON   UK  EC1V 2NX
# 8                        LONDON   UK  EC1A 2DJ
# 9                        LONDON   UK  EC1V 7JL
# 10                       LONDON   UK  EC1V 2PT
# 11                       LONDON   UK  EC1V 2NX
# 12                       LONDON   UK  EC1Y 4TW
# 13                       LONDON   UK  EC1V 4PY
# 14                       LONDON   UK  EC1N 8PN
# 15                       LONDON   UK  EC1A 2BN
# 16                       LONDON   UK  EC1A 4EE
# 17                       LONDON   UK  EC1M 6AW
# 18                       LONDON   UK  EC1R 0NE
# 19                       LONDON   UK  EC1V 4PW
# 20                       LONDON   UK  EC1V 2NX
# 21        CITY OF LONDON|LONDON   UK  EC1A 2BN
# 22                       LONDON   UK  EC1N 8NX
# 23                       LONDON   UK  EC1M 3HE
# 24                       LONDON   UK  EC1Y 0SW
# 25                       LONDON   UK  EC1V 4PW
# 26                       LONDON   UK  EC1M 4DH
# 27                       LONDON   UK  EC1R 4RB
# 28                       LONDON   UK  EC1V 2NX
# 29                       LONDON   UK  EC1V 4UB
# ..                          ...  ...       ...
# 970                      LONDON   UK  SW16 4AH
# 971          HOUNSLOW|MIDDLESEX   UK   TW3 3AD
# 972            HARROW|MIDDLESEX   UK   HA1 2EY
# 973            HOVE|EAST SUSSEX   UK   BN3 6HA
# 974                      LONDON   UK  EC2A 1AF
# 975                     ROMFORD   UK   RM2 5DJ
# 976                      SURREY   UK  GU10 4PA
# 977        CARNFORTH|LANCASHIRE   UK   LA6 2GT
# 978              FARNHAM|SURREY   UK   GU9 7XX
# 979                      LONDON   UK  SW12 8AZ
# 980                ILFORD|ESSEX   UK   IG1 2SB
# 981  GLOUCESTER|GLOUCESTERSHIRE   UK   GL1 2EX
# 982                   CAMBRIDGE   UK  CB23 1HR
# 983                      LONDON   UK   N16 0EH
# 984          STOCKPORT|CHESHIRE   UK  SK12 1LQ
# 985                      LONDON   UK    N3 2LT
# 986             COULSDON|SURREY   UK   CR5 1AN
# 987                  MERSEYSIDE   UK  CH45 7QL
# 988          STANMORE|MIDDLESEX   UK   HA7 1JS
# 989            HOVE|EAST SUSSEX   UK   BN3 6HA
# 990          LEIGH-ON-SEA|ESSEX   UK   SS9 1SU
# 991                     NORFOLK   UK  PE37 7QH
# 992                   CAMBRIDGE   UK  CB24 8RX
# 993               COBHAM|SURREY   UK  KT11 3DP
# 994                  BIRMINGHAM   UK   B24 9JE
# 995                     RUTLAND   UK  LE15 6RA
# 996            HASLEMERE|SURREY   UK  GU27 2LA
# 997             NORWICH|NORFOLK   UK   NR8 6HW
# 998                      LONDON   UK   E14 5AA
# 999                      LONDON   UK   NW1 8NZ
#
# [1000 rows x 6 columns]

# %%
dfB
# Out:
#    id     name          addr    city ctry      code
# 0   1  company  30 CITY ROAD  LONDON   UK  EC1Y 2AB

# %% [markdown]
# ## 3. Make Record Pairs

# %% [markdown]
# ### 3.1 Block Indexing for Record Pairs

# %%
#############   BLOCK INDEXING
def runBlock():  
    block = 0
    
    #Next, check for exact match in name
    blockName = recordlinkage.BlockIndex(on=['name'])
    blockNamePairs = blockName.index(dfA, dfB)
    if len(blockNamePairs) > 0:
         block += 1
    
    #Next, check for exact match in addr    
    blockAddr = recordlinkage.BlockIndex(on=['addr'])
    blockAddrPairs = blockAddr.index(dfA, dfB)
    if len(blockAddrPairs) > 0:
        block += 2
        
    #Next, check for exact match in name AND addr    
    blockNA = recordlinkage.BlockIndex(on=['name','addr'])
    blockNAPairs = blockNA.index(dfA, dfB)
    if len(blockNAPairs) > 0:
        block = 4    
    
    
    if block == 0:
    #run sorted neighborhood both
        runSort()
    if block == 1:
    #grab the id and contents of name match
        print("block name match")
        return(returnResultsMI(blockNamePairs))
        print(blockNamePairs)
    if block == 2:
        #grab the id and contents of addr match
        print("block addr match")
        return(returnResultsMI(blockAddrPairs))
    if block == 3:
        #grab the id and contents of addr match
        print("block different name and addr match")        
    if block == 4:
    #grab the id and contents of addr match
        print("block name and addr match")
        return(returnResultsMI(blockNAPairs))
###############

# %% [markdown]
# ### 3.2 Sorted Neighborhood Indexing

# %%
#############   SORTED NEIGHBORHOOD INDEXING
def runSort():
    sort = 0

    sortedNameIndexer = recordlinkage.SortedNeighbourhoodIndex(on='name')
    sortedNamePairs = sortedNameIndexer.index(dfA, dfB)
    if len(sortedNamePairs) > 0:
        sort += 1

    sortedAddrIndexer = recordlinkage.SortedNeighbourhoodIndex(on='addr')
    sortedAddrPairs = sortedAddrIndexer.index(dfA, dfB)
    if len(sortedAddrPairs) > 0:
        sort += 2

    if sort == 0:
        #run sorted neighborhood both
        print("full index NEXT")
        runFull()
    if sort == 1:
        #compare with name pairs
        print("sort name match")
        runCompare(sortedNamePairs)
    if sort == 2:
        #compare with addr pairs
        print("sort addr match")
        runCompare(sortedAddrPairs)
    if sort == 3:
        #compare with both pairs?
        print("sort both match")
        runFull()

# %% [markdown]
# ### 4. Compare Record Pairs

# %%
######### COMPARE
def runCompare():
    
    compare = recordlinkage.Compare()

    compare.string('name', 'name', method='jarowinkler', threshold=0.95)
    compare.string('addr', 'addr', method='jarowinkler', threshold=0.95)
    compare.exact('city', 'city')
    compare.exact('ctry', 'ctry')
    compare.string('code', 'code', method='jarowinkler', threshold=0.90)

    ######### Specify to neighborhood

    # The comparison vectors for name
    featuresName = compare.compute(sortedNamePairs, dfA, dfB)

    # The comparison vectors for addr
    featuresAddr = compare.compute(sortedAddrPairs, dfA, dfB)

    ########## Classification

    featuresName.sum(axis=1).value_counts().sort_index(ascending=False)
    featuresAddr.sum(axis=1).value_counts().sort_index(ascending=False)
    
    runMatch()

# %% [markdown]
# ### 5. Classification and Matching

# %%
# Classification step
def runMatch():
    match = 0

    matchesNameAll = featuresName[featuresName.sum(axis=1) > 4]
    if len(matchesNameAll) > 0:
        match += 1 
        matchesName = matchesNameAll #overwriting the larger set of results
    else:
        matchesName = featuresName[featuresName.sum(axis=1) > 3]
        if len(matchesName) > 0:
            match += 1
    print(len(matchesName))

    matchesAddrAll = featuresAddr[featuresAddr.sum(axis=1) > 4]
    if len(matchesAddrAll) > 0:
        match += 2 
        matchesAddr = matchesAddrAll #overwriting the larger set of results
    else:
        matchesAddr = featuresAddr[featuresAddr.sum(axis=1) > 3]
        if len(matchesAddr) > 0:
            match += 2
    print(len(matchesAddr))

    ########## FSM

    if match == 0:
        #run sorted neighborhood both
        print("Full Index NEXT")
        runFull()
    if match == 1:
        #grab the id and contents of name match
        print("sort name match")
        return(returnResultsDF(matchesName))
    if match > 1:
        #grab the id and contents of addr match, 11 = preference towards addr
        print("sort addr match")
        return(returnResultsDF(matchesAddr))

# %% [markdown]
# ### 6. Full Index Pairs and Classification

# %%
####### If nothing else finds matches, run FULL INDEX
def runFull():
    compare = recordlinkage.Compare()

    compare.string('name', 'name', method='jarowinkler', threshold=0.95)
    compare.string('addr', 'addr', method='jarowinkler', threshold=0.95)
    compare.exact('city', 'city')
    compare.exact('ctry', 'ctry')
    compare.string('code', 'code', method='jarowinkler', threshold=0.90)
    
    fullIndexer = recordlinkage.FullIndex()
    fullIndexPairs = fullIndexer.index(dfA, dfB)

    featuresFull = compare.compute(fullIndexPairs, dfA, dfB)

    matchesFullAll = featuresFull[featuresFull.sum(axis=1) > 4]
    if len(matchesFullAll) > 0:
        print("full match all")
        return(returnResultsDF(matchesFullAll))
    else:
        matchesFull = featuresFull[featuresFull.sum(axis=1) > 3]
        print("full match")
        #print(type(matchesFull))
        return(returnResultsDF(matchesFull))
    #return the match/matches with highest sum. Maybe try >4 first then >3. for row in frame, 
    #grab id then return the full dict entry of the id

# %% [markdown]
# ### 7. Return Results

# %%
######## RETURN FROM MULTIINDEX

def returnResultsMI(pairs):
    data = pairs.to_frame(index = False)[0]
    i = 0
    grab_ids = []
    while i < len(data):
        grab_ids.append(data[i])
        i+=1   
    for grab_id in grab_ids:
        result = dfD.loc[grab_id].to_string(header = False, index = False)
        results.append(result)
    return results

def returnResultsDF(pairs):
    data = pairs[0]
    i = 0
    grab_ids = []
    while i < len(data):
        grab_ids.append(data[i])
        i+=1   
    for grab_id in grab_ids:
        result = dfD.loc[grab_id].to_string(header = False, index = False)
        results.append(result)
    return results

# %% [markdown]
# ### 8. Main Method to Run

# %%
### MAIN METHOD
# First, check for exact match overall FULL
results = []
blockIndexer = recordlinkage.BlockIndex(on=['name', 'addr', 'city', 'ctry', 'code'])
blockIndexPairs = blockIndexer.index(dfA, dfB)
if len(blockIndexPairs) > 0:
    #continue
    print(returnResults(blockIndexPairs))
else:
    runBlock()

print(results)
# Out:
# block addr match
# ['1 MOBILE LIMITED 30 CITY ROAD LONDON EC1Y 2AB', '4D DATA CENTRES LIMITED 30 CITY ROAD LONDON EC...', 'NCSOFT EUROPE LIMITED 30 CITY ROAD LONDON EC1Y...']

# %% [markdown]
# ### 9. Output to the UI, Variable outputRL, Based on Result Length

# %%
## OUTPUT TO UI
outputRL = ""

if len(results) == 0:
    outputRL = "No results were found using Record Linkage"
if len(results) == 1:
    outputRL = "Did you mean: " + results[0] + " ?"
if len(results) == 2:
    outputRL = "Did you mean: " + results[0] + " ?" + "\n" + "Or possibly: " + results[1] + " ?"    
if len(results) == 3:
    outputRL = "Did you mean: " + results[0] + " ?" + "\n" + "Or possibly: " + results[1] + " ?" + "\n" + "Or possibly this: " + results[2] + " ?"    
if len(results) > 3:
    outputRL = "Number of results: " + str(len(results)) + ". Too many match results found. Please enter new data."

print(outputRL)
# Out:
# Did you mean: 1 MOBILE LIMITED 30 CITY ROAD LONDON EC1Y 2AB ?
# Or possibly: 4D DATA CENTRES LIMITED 30 CITY ROAD LONDON EC... ?
# Or possibly this: NCSOFT EUROPE LIMITED 30 CITY ROAD LONDON EC1Y... ?
